# %%
def maxProfit(prices: List[int]) -> int:
    buy = 0
    sell = 0
    profit = float('-inf')

    for sell in range(len(prices)):
        current_profit = prices[sell] - prices[buy]
        profit = max(current_profit, profit)
        if prices[sell] < prices[buy]:
            buy = sell
    return profit

# %%
prices=[2,1,2,1,0,1,2]
result = maxProfit(prices)
print(result)
# Out:
# 2

# %%
def lengthOfLongestSubstring(s: str) -> int:
    r = l = 0
    seen = set()
    window = 0

    for elem in s:
        print("right is ", r)
        print("left is ", l)
        print("elem is ",elem)
        if elem not in seen:
            current_window = (r-l+1)
            r = r + 1
            seen.add(elem)
            print(f"seen after addition is {seen}")
        else:
            print("Got duplicate item")
            seen.remove(elem)
            print(f"seen after removal is {seen}")
            l = l+1
            current_window = (r-l+1)
            r = r+1
            
        # current_window = (r-l+1)
        print("current_window is ",current_window)
        window = max(current_window, window)
        print("window is ",window)

    return window

# %%
s="abcabcbb"
result = lengthOfLongestSubstring(s)
# Out:
# right is  0
# left is  0
# elem is  a
# seen after addition is {'a'}
# current_window is  1
# window is  1
# right is  1
# left is  0
# elem is  b
# seen after addition is {'a', 'b'}
# current_window is  2
# window is  2
# right is  2
# left is  0
# elem is  c
# seen after addition is {'a', 'c', 'b'}
# current_window is  3
# window is  3
# right is  3
# left is  0
# elem is  a
# Got duplicate item
# seen after removal is {'c', 'b'}
# current_window is  3
# window is  3
# right is  4
# left is  1
# elem is  b
# Got duplicate item
# seen after removal is {'c'}
# current_window is  3
# window is  3
# right is  5
# left is  2
# elem is  c
# Got duplicate item
# seen after removal is set()
# current_window is  3
# window is  3
# right is  6
# left is  3
# elem is  b
# seen after addition is {'b'}
# current_window is  4
# window is  4
# right is  7
# left is  3
# elem is  b
# Got duplicate item
# seen after removal is set()
# current_window is  4
# window is  4

# %%
class Solution:
    def checkInclusion(self, s1: str, s2: str) -> bool:
        if len(s1) > len(s2):
            return False

        s1Count, s2Count = [0] * 26, [0] * 26
        for i in range(len(s1)):
            s1Count[ord(s1[i]) - ord('a')] += 1
            s2Count[ord(s2[i]) - ord('a')] += 1

        matches = 0
        for i in range(26):
            matches += (1 if s1Count[i] == s2Count[i] else 0)

        l = 0
        for r in range(len(s1), len(s2)):
            if matches == 26:
                return True

            index = ord(s2[r]) - ord('a')
            s2Count[index] += 1
            if s1Count[index] == s2Count[index]:
                matches += 1
            elif s1Count[index] + 1 == s2Count[index]:
                matches -= 1

            index = ord(s2[l]) - ord('a')
            s2Count[index] -= 1
            if s1Count[index] == s2Count[index]:
                matches += 1
            elif s1Count[index] - 1 == s2Count[index]:
                matches -= 1
            l += 1
        return matches == 26
# Out:
# 4

# %%
s = "sourav"
lkp = set(s)

print("s" in lkp)
# Out:
# True
